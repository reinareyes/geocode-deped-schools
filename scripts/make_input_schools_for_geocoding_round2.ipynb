# %%
import numpy as np
import pandas as pd

# %%
fn = "../data/deped_school_location_with_enrolment_2017_2018_validationA.csv"
df = pd.read_csv(fn)
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fn_out = "../input/schools_for_geocoding_round2.csv"

# %%
df.head(2)
# Out:
#    SCHOOL ID SCHOOL NAME                       ADDRESS    REGION  \
# 0     100160   Adams CES   Pob. 1, Adams, Ilocos Norte  Region I
# 1     100163  Bucarot PS  Bucarot, Adams, Ilocos Norte  Region I
#
#        DIVISION MUNICIPALITY     BARANGGAY   LATITUDE   LONGITUDE  MAPPED  \
# 0  Ilocos Norte        ADAMS  ADAMS (POB.)  18.462302  120.901845       1
# 1  Ilocos Norte        ADAMS  ADAMS (POB.)  18.462088  120.903605       1
#
#    ...                  Reg_Name     Pro_Code      Pro_Name     Mun_Code  \
# 0  ...  REGION I (ILOCOS REGION)  PH012800000  ILOCOS NORTE  PH012801000
# 1  ...  REGION I (ILOCOS REGION)  PH012800000  ILOCOS NORTE  PH012801000
#
#   Mun_Name     Bgy_Code      Bgy_Name MATCH_BARANGAY MATCH_MUNICIPALITY  \
# 0    ADAMS  PH012801001  ADAMS (POB.)            1.0                1.0
# 1    ADAMS  PH012801001  ADAMS (POB.)            1.0                1.0
#
#    MATCH_REGION
# 0           1.0
# 1           1.0
#
# [2 rows x 22 columns]

# %%
# get mapped schools with locations outside PH shapefile (invalid is NULL)
# AND mapped schools with mismatching locations (invalid = 1, i.e. with both municipality and regions not matching)
df_out = df[(df["MAPPED"]==1) & ((df["INVALID"].isnull()) | (df["INVALID"]==1))]
len(df_out)
# Out:
# 502

# %%
# define full school name 
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME"].str.upper()
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" CES", " Central Elementary School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" CS", " Central School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" ES", " Elementary School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" E/S", " Elementary School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" ELEM. SCHOOL", " Elementary School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" INTEG. SCH.", " Integrated School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" IS", " Integrated School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" MNHS", " Memorial National High School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" MEM. NATIONAL", " Memorial National")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" NHS", " National High School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" SHS", " Senior High School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace("SHS ", "Senior High School ")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" HS", " High School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" PS", " Primary School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" P/S", " Primary School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace("TUBIGKUTAHPS", "TubigKutah Primary School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace("GNHS", "Guihulngan National High School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" VOC", " VOCATIONAL")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" NTS", " NATIONAL TRADE SCHOOL")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" NSTS", " NATIONAL SECONDARY TRADE SCHOOL")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" MS", " Memorial School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" MES", " Memorial Elementary School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" COMM. SCH.", " Community School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" RVS", " Rural and Vocational School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace(" SOF", " School of Fisheries")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace("MALAPOC SUR MGS", "Malapoc Sur Elementary School")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.replace("PHI SCIENCE", "PHILIPPINE SCIENCE")
df_out["SCHOOL NAME2"] = df_out["SCHOOL NAME2"].str.upper()
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# convert all strings to upper case
for col in "SCHOOL NAME", "ADDRESS", "REGION", "DIVISION", "MUNICIPALITY", "BARANGGAY":
    df_out[col] = df_out[col].str.upper()
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# create input text address for geocoding
# address1 - with school name
# address2 - without school name; for validating if coordinates are tied to the school
df_out["ADDRESS"] = df_out["ADDRESS"].fillna("")
# start with the school name and address
address = df_out["ADDRESS"]
# if not included, add barangay 
sub = df_out.loc[df_out["BARANGGAY"].isin(address)==False, "BARANGGAY"]
address[df_out["BARANGGAY"].isin(address)==False] = address[df_out["BARANGGAY"].isin(address)==False] + ", BRGY. " + sub 
# if not included, add municipality
sub = df_out.loc[df_out["MUNICIPALITY"].isin(address)==False, "MUNICIPALITY"]
address[df_out["MUNICIPALITY"].isin(address)==False] = address[df_out["MUNICIPALITY"].isin(address)==False] + ", " + sub 
# add country
address = address + ", PHILIPPINES"
# set ADDRESS1, ADDRESS2
df_out["ADDRESS1"] = df_out["SCHOOL NAME2"] + ", " + address # with expanded school name
df_out["ADDRESS2"] = address
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/anaconda2/lib/python2.7/site-packages/pandas/core/generic.py:8682: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /opt/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2878: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_out.to_csv(fn_out, index=False)

# %%
df_out.head()
# Out:
#       SCHOOL ID    SCHOOL NAME  \
# 930      100850  NANGALISAN ES
# 949      100864       LIBBO ES
# 1123     101000      PALINA ES
# 1135     101008    CARUNOAN ES
# 1151     101054       NAYBA ES
#
#                                              ADDRESS    REGION  DIVISION  \
# 930                    -, BRGY. NANGALISAN, BACNOTAN  REGION I  LA UNION
# 949   LIBBO, BAGULIN ,LA UNION, BRGY. LIBBO, BAGULIN  REGION I  LA UNION
# 1123               MARCOS HI-WAY, BRGY. PALINA, PUGO  REGION I  LA UNION
# 1135                 -, BRGY. CARUNUAN EAST, ROSARIO  REGION I  LA UNION
# 1151                    -, BRGY. APAYAO, SAN GABRIEL  REGION I  LA UNION
#
#      MUNICIPALITY      BARANGGAY     LATITUDE   LONGITUDE  MAPPED  ...  \
# 930      BACNOTAN     NANGALISAN  16.43410278  120.479775       1  ...
# 949       BAGULIN          LIBBO    16.570025  120.524387       1  ...
# 1123         PUGO         PALINA    16.342535  120.493935       1  ...
# 1135      ROSARIO  CARUNUAN EAST      16.1536  120.271477       1  ...
# 1151  SAN GABRIEL         APAYAO    16.642738  120.546997       1  ...
#
#          Mun_Code  Mun_Name     Bgy_Code    Bgy_Name MATCH_BARANGAY  \
# 930   PH141113000      TUBA  PH141113006  NANGALISAN            1.0
# 949   PH141108000  KAPANGAN  PH141108010   GASWELING            0.0
# 1123  PH141113000      TUBA  PH141113013   TALOY SUR            0.0
# 1135          NaN       NaN          NaN         NaN            NaN
# 1151  PH141108000  KAPANGAN  PH141108009      GADANG            0.0
#
#      MATCH_MUNICIPALITY MATCH_REGION                  SCHOOL NAME2  \
# 930                 0.0          0.0  NANGALISAN ELEMENTARY SCHOOL
# 949                 0.0          0.0       LIBBO ELEMENTARY SCHOOL
# 1123                0.0          0.0      PALINA ELEMENTARY SCHOOL
# 1135                NaN          NaN    CARUNOAN ELEMENTARY SCHOOL
# 1151                0.0          0.0       NAYBA ELEMENTARY SCHOOL
#
#                                                ADDRESS1  \
# 930   NANGALISAN ELEMENTARY SCHOOL, -, BRGY. NANGALI...
# 949   LIBBO ELEMENTARY SCHOOL, LIBBO, BAGULIN ,LA UN...
# 1123  PALINA ELEMENTARY SCHOOL, MARCOS HI-WAY, BRGY....
# 1135  CARUNOAN ELEMENTARY SCHOOL, -, BRGY. CARUNUAN ...
# 1151  NAYBA ELEMENTARY SCHOOL, -, BRGY. APAYAO, SAN ...
#
#                                                ADDRESS2
# 930          -, BRGY. NANGALISAN, BACNOTAN, PHILIPPINES
# 949   LIBBO, BAGULIN ,LA UNION, BRGY. LIBBO, BAGULIN...
# 1123     MARCOS HI-WAY, BRGY. PALINA, PUGO, PHILIPPINES
# 1135       -, BRGY. CARUNUAN EAST, ROSARIO, PHILIPPINES
# 1151          -, BRGY. APAYAO, SAN GABRIEL, PHILIPPINES
#
# [5 rows x 25 columns]
